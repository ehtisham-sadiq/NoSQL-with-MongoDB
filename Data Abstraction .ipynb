# %% [markdown]
# <h1 align="center">Data Abstraction using MongoDB and SQL</h1>

# %% [markdown]
# ### Agenda of Notebook
#
# - **What is a database?**
# - **MongoDB**
#     - Installing PyMongo
#     - Importing Libraries
#     - Connecting to the database
#     - Checking all the collections present in the database
#     - Connecting to the collection
#     - Counting the number of documents in the collection
#     - Checking all the documents
#     - Importing data from MongoDB to Notebook
#     - Converting data to CSV
#
# - **MySQL**
#     - Installing MySQL
#     - Importing Libraries
#     - Connecting to the database
#     - Getting the list of all the tables in our DB
#     - Fetching and calling the data in our notebook
#     - Saving it as a CSV

# %% [markdown]
# > **Note:** Here, We will be pulling the Telecom Churn Data from the MongoDB into our notebook and convert it to CSV.

# %% [markdown]
# ## What is Database?
#
# <img src="images/intro_db.jpg" height=400px width=400px>
#
# - A database is an **ordered collection of information** (data) that can be easily accessed and managed.
#
# - The main purpose of databases is to **handle the humongous(massive)** amount of data by storing, retrieving and managing.
#
# - Many different examples of databases are MySQL, MariaDB, MongoDB, PostgreSQL and so on.

# %% [markdown]
# ## What is MongoDB?
#
# <img src="images/intro_mongodb.jpeg" height=400px width=400px>
#
#
#
# - MongoDB is a **document database**, it stores data in _JSON-like documents_.
# - Support for modern use-cases like:
#     - geo-based search
#     - graph search
#     - Text search.
# - **Queries are themselves JSON**, and thus easily composable.
#
#
# ### Advantages:
# - Flexible Database
# - Fast Query Response
# - Horizontally Scalable Database
# - Easier to setup
# - Store a large data by distributing it to serveral servers connected to the application
#
# ### Disadvantages
# - Document size cannot be more than 16MB.
# - No nesting of documents for more than 100 levels.
# - Unnecessary usage of memory, due to no functionality of joins.

# %% [markdown]
# ## what is MySQL?
#
# <img src="images/mysql.jpg" height=400px width=400px>
#
# - **Relational Database Management System** that allows you to manage relational databases.
# - It is **open-source** software backed by Oracle.
# - MySQL can run on various platforms UNIX, Linux, Windows, etc.
#
# ### Advantages:
# - Easy to Use
# - MySQL stored procedures are fast because the MySQL server takes some advantage of caching.
# - Free version of MySQL is fully features.
# - Widely used in the industry.
#
# ### Disadvantages
# - Less efficient with very large datasets
# - MySQL does not provide facilities for debugging stored procedures.

# %%
# !ls images/

# %% [markdown]
# ## Case Study
#
# ### Problem Statement
#
# Due to the boom in the telecom industry with 4G/5G technology, it has become a pain in the neck for the company to retain their customers.
#
# <img src="images/telecom.webp" height=500px width=500px>
#
# - They are in the middle of setting up more cell sites on the 4G network to improve their 4G services.
# - It is plausible(reasonable) for customers to choose 4G services over 3G Services due to benefits of cost, speed, latency etc.
#
# - Till now they have been using manual traditional ways which now has become a problem to handle due to work complication.
#
# <img src="images/churn.jpg" height=500px width=500px>
#
#
# - They have a detailed history of their customers and are looking for an automaed solution toidentify the linkeliness of customer churing from using their services.
# - The data is **stored** in their **MongoDB** and you need to **extract to move further with your Data Science Skills**

# %% [markdown]
# ### Installing and Importing Libraries
#
# #### Installing Libraries

# %%
# !pip3 install pymongo[srv]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.8/dist-packages (3.13.0)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 938.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Installing collected packages: dnspython
# Successfully installed dnspython-2.3.0

# %%
# check version of pymongo
# !pip3 show pymongo
# Out:
# Name: pymongo
# Version: 3.13.0
# Summary: Python driver for MongoDB <http://www.mongodb.org>
# Home-page: http://github.com/mongodb/mongo-python-driver
# Author: Mike Dirolf
# Author-email: mongodb-user@googlegroups.com
# License: Apache License, Version 2.0
# Location: /usr/local/lib/python3.8/dist-packages
# Requires:
# Required-by: apache-beam

# %% [markdown]
# #### Importing Libraries

# %%
from pymongo import MongoClient
import urllib
import pandas as pd
import json
import numpy as np
from bson import ObjectId

# %% [markdown]
# > **Note:** `BSON` stands for Binary Javascript Object Notation. It is a binary-encoded serialization of JSON documents. BSON has been extended to add some optional non-JSON-native data types, like dates and binary data.

# %% [markdown]
# ## Data Acquisition using MongoDB

# %% [markdown]
# #### Calling MongoClient to connect to our database

# %%
string_mongo = "Connection string"

# %% [markdown]
# > **Note:** The `connection string` in the `MongoClient()` method is a URL that specifies the location of a `MongoDB server instance`. It provides the necessary information for the MongoClient to establish a connection with the server, including the `server host name` and `port number`, as well as any `authentication credentials` required to access the database.

# %%
client = MongoClient("mongodb+srv://<username>:<password>@cluster.mongodb.net/test?retryWrites=true&w=majority")

# %% [markdown]
# **Where:**
#
# - `mongodb+srv` is a protocol for connecting to a MongoDB Atlas cluster.
# - `<username>` and `<password>` are the credentials for accessing the MongoDB Atlas cluster.
# - `cluster.mongodb.net` is the hostname of the MongoDB Atlas cluster.
# - `test` is the name of the database to connect to.
# - `retryWrites=true` and `w=majority` are additional options for the connection.
#
# Note that when you create a MongoDB Atlas cluster, you will be provided with a unique connection string that you should use in your applications.

# %% [markdown]
# **Original Connection string**
#
# mongodb+srv://raiehtishamsadiq:password@cluster0.opn3gix.mongodb.net/database_name?retryWrites=true&w=majority

# %%
string_mongo = "mongodb+srv://raiehtishamsadiq:Pucit12345@cluster0.opn3gix.mongodb.net/Telecom?retryWrites=true&w=majority"
# client = MongoClient("mongodb+srv://raiehtishamsadiq:Pucit12345@cluster0.opn3gix.mongodb.net/?retryWrites=true&w=majority")
client = MongoClient(string_mongo)

# %%
db = client['Telecom']

# %%
db
# Out:
# Database(MongoClient(host=['ac-qv7vyhr-shard-00-01.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-00.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-02.opn3gix.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-k61qaf-shard-0', ssl=True), 'Telecom')

# %% [markdown]
# #### Getting List of all the collections in our DB

# %%
db.list_collection_names()
# Out:
# ['Churn']

# %%
db_c = db['Churn']

# %% [markdown]
# #### Counting number of Documents in our Collection

# %%
db_c.count_documents({})
# Out:
# 2

# %% [markdown]
# #### Finding the correct Document

# %%
# see all the documents in the collection

cursor = db_c.find({})
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('63d9e76369aa5c9835d236ec'), 'columns': ['state', 'account length', 'area code', 'phone number', 'international plan', 'voice mail plan', 'number vmail messages', 'total day minutes', 'total day calls', 'total day charge', 'total eve minutes', 'total eve calls', 'total eve charge', 'total night minutes', 'total night calls', 'total night charge', 'total intl minutes', 'total intl calls', 'total intl charge', 'customer service cal
, 20.37, 208.8, 133, 9.4, 10.6, 4, 2.86, 0, False], ['CO', 77, 408, '393-7984', 'no', 'no', 0, 62.4, 89, 10.61, 169.9, 121, 14.44, 209.6, 64, 9.43, 5.7, 6, 1.54, 5, True], ['AZ', 130, 415, '358-1958', 'no', 'no', 0, 183.0, 112, 31.11, 72.9, 99, 6.2, 181.8, 78, 8.18, 9.5, 19, 2.57, 0, False], ['SC', 111, 415, '350-2565', 'no', 'no', 0, 110.4, 103, 18.77, 137.3, 102, 11.67, 189.6, 105, 8.53, 7.7, 6, 2.08, 2, False], ['VA', 132, 510, '343-4696', 'no', 'no', 0, 81.1, 86, 13.79, 245.2, 72, 20.84, 237.0, 115, 10.67, 10.3, 2, 2.78, 0, False], ['NE', 174, 415, '331-3698', 'no', 'no', 0, 124.3, 76, 21.13, 277.1, 112, 23.55, 250.7, 115, 11.28, 15.5, 5, 4.19, 3, False], ['WY', 57, 408, '357-3817', 'no', 'yes', 39, 213.0, 115, 36.21, 191.1, 112, 16.24, 182.7, 115, 8.22, 9.5, 3, 2.57, 0, False], ['MT', 54, 408, '418-6412', 'no', 'no', 0, 134.3, 73, 22.83, 155.5, 100, 13.22, 102.1, 68, 4.59, 14.7, 4, 3.97, 3, False], ['MO', 20, 415, '353-2630', 'no', 'no', 0, 190.0, 109, 32.3, 25 ...
# {'_id': ObjectId('63d9f3ac69aa5c9835d236ef'), 'state': {'0': 'KS', '1': 'OH', '2': 'NJ', '3': 'OH', '4': 'OK', '5': 'AL', '6': 'MA', '7': 'MO', '8': 'LA', '9': 'WV', '10': 'IN', '11': 'RI', '12': 'IA', '13': 'MT', '14': 'IA', '15': 'NY', '16': 'ID', '17': 'VT', '18': 'VA', '19': 'TX', '20': 'FL', '21': 'CO', '22': 'AZ', '23': 'SC', '24': 'VA', '25': 'NE', '26': 'WY', '27': 'MT', '28': 'MO', '29': 'HI', '30': 'IL', '31': 'NH', '32': 'LA', '33': 'AZ', '34': 'OK', '35': 'GA', '36': 'AK', '37': 'MA', '38': 'AK', '39': 'NJ', '40': 'GA', '41': 'MD', '42': 'AR', '43': 'ID', '44': 'WI', '45': 'OR', '46': 'MI', '47': 'DE', '48': 'ID', '49': 'WY', '50': 'IA', '51': 'IN', '52': 'VA', '53': 'UT', '54': 'WY', '55': 'IN', '56': 'CO', '57': 'CO', '58': 'WI', '59': 'OK', '60': 'ID', '61': 'CA', '62': 'MN', '63': 'SD', '64': 'NC', '65': 'WA', '66': 'WY', '67': 'MN', '68': 'UT', '69': 'TX', '70': 'NJ', '71': 'MN', '72': 'NM', '73': 'NV', '74': 'HI', '75': 'MN', '76': 'DC', '77': 'NY', '78': 'MN', '79': 'MD', '80': 'WV', '81': 'OR', '82': 'CO', '83': 'GA', '84': 'TX', '85': 'VT', '86': 'IN', '87': 'WV', '88': 'KY', '89': 'NJ', '90': 'DC', '91': 'LA', '92': 'AR', '93': 'ME', '94': 'AZ', '95': 'AK', '96': 'MT', '97': 'AZ', '98': 'MS', '99': 'ID', '100': 'IA', '101': 'MA', '102': 'VT', '103': 'KY', '104': 'IN', '105': 'AZ', '106': 'MI
# %% [markdown]
# It is same as mentioned on MongoDB server
#
# <img src="images/p3.png">

# %% [markdown]
# #### fetching and calling the data in our notebook

# %%
mongo_docs = db_c.find({'id':ObjectId('63d9e76369aa5c9835d236ec')})

# %%
mongo_docs

# %% [markdown]
# #### Converting MongoDB's JSON format to CSV

# %%
fields = {}
for doc in mongo_docs:
    for key, val in doc.items():
        try:
            fields[Key] = np.append(fields[key], val)
        except KeyError:
            fields[key] = np.array([val])
print(fields)
# Out:
# {}

# %% [markdown]
# ## MySQL
#
# - Relational Database Management System that allows you to manage relational databases.
# - It is open-source software backed by Oracle.
# - MySQL can run on various platforms UNIX, Linux, Windows, etc.

# %% [markdown]
# ### Installing Library

# %%
# !pip3 install pymysql -q

# %% [markdown]
# ### Importing Libraries

# %%
import pymysql
import pandas as pd
pymysql.__version__
# Out:
# '1.0.2'

# %% [markdown]
# ### Connecting to our database

# %%
conn = pymysql.connect(host='localhost',
                         user='root',
                         password='Pucit12345#',
                         db='ranking')
cursor = conn.cursor()

# %% [markdown]
# ### Getting the list of all the tables in our DB

# %%
cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'ranking'")
for table in [tables[0] for tables in cursor.fetchall()]:
    print(table)
# Out:
# DataTable

# %% [markdown]
# ### Fetching and calling the data in our notebook

# %%
query = 'select * from DataTable'
results = pandas.read_sql_query(query, conn)
results.head()
# Out:
# /home/dell/.local/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    Rank                                   institution location code  \
# 0     1  Massachusetts Institute of Technology (MIT)             US
# 1     2                       University of Cambridge            UK
# 2     3                           Stanford University            US
# 3     4                          University of Oxford            UK
# 4     5                            Harvard University            US
#
#          location  SCORE  ar rank  er score  fsr score fsr rank  cpf score  \
# 0   United States    100        5       100        100       14        100
# 1  United Kingdom    100        2       100        100       11         92
# 2   United States    100        4       100        100        6         99
# 3  United Kingdom    100        3       100        100        8         90
# 4   United States    100        1       100         99       35        100
#
#   cpf rank  ifr score ifr rank  isr score isr rank  irn score irn rank  \
# 0        5      100.0       54         90      109       96.1       58
# 1       55      100.0       60         96       70       99.5        6
# 2        9       99.0       74         60      235       96.3       55
# 3       64       98.0      101         98       54       99.9        3
# 4        2       76.0      228         66      212      100.0        1
#
#    ger score ger rank  score scaled
# 0        100        3           100
# 1        100        9            98
# 2        100        2            98
# 3        100        7            98
# 4        100        1            97

# %%
type(results)
# Out:
# pandas.core.frame.DataFrame

# %%
results.dtypes
# Out:
# Rank               int64
# institution       object
# location code     object
# location          object
# SCORE              int64
# ar rank            int64
# er score           int64
# fsr score          int64
# fsr rank          object
# cpf score          int64
# cpf rank          object
# ifr score        float64
# ifr rank          object
# isr score          int64
# isr rank          object
# irn score        float64
# irn rank          object
# ger score          int64
# ger rank          object
# score scaled       int64
# dtype: object

# %%
results.shape
# Out:
# (976, 20)

# %% [markdown]
# ### Saving it as a CSV

# %%
results.to_csv("ranking.csv", index=False)

# %%
# !ls
# Out:
# 'Data Abstraction .ipynb'   images		       ranking.csv
#  datasets		    NoSQL-with-MongoDB.ipynb   README.md

# %% [markdown]
# # Bonus : Importing Dataset-CSV to MongoDB

# %%
df = pd.read_csv('datasets/churn_dataset.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
#
# [5 rows x 21 columns]

# %%
# df.to_json('datasets/churn.json')
data = df.to_dict("images/records", orient='split')
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [113], in <cell line: 2>()
#       1 # df.to_json('datasets/churn.json')
# ----> 2 data = df.to_dict("images/records", orient='split')
#       3 data
#
# TypeError: to_dict() got multiple values for argument 'orient'

# %%
client
# Out:
# MongoClient(host=['ac-qv7vyhr-shard-00-01.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-00.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-02.opn3gix.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-k61qaf-shard-0', ssl=True)

# %%
db_churn = client['Telecom']
db_churn
# Out:
# Database(MongoClient(host=['ac-qv7vyhr-shard-00-01.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-00.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-02.opn3gix.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-k61qaf-shard-0', ssl=True), 'Telecom')

# %%
db_churn_c = db_churn['Churn']
db_churn_c
# Out:
# Collection(Database(MongoClient(host=['ac-qv7vyhr-shard-00-01.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-00.opn3gix.mongodb.net:27017', 'ac-qv7vyhr-shard-00-02.opn3gix.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-k61qaf-shard-0', ssl=True), 'Telecom'), 'Churn')

# %%
collection.insert_many(data)

# %%
db_churn_c.insert_many([data])
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 db_churn_c.insert_many([data])
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/collection.py:815, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session)
#     813 blk = _Bulk(self, ordered, bypass_document_validation)
#     814 blk.ops = [doc for doc in gen()]
# --> 815 blk.execute(write_concern, session=session)
#     816 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/bulk.py:557, in _Bulk.execute(self, write_concern, session)
#     555         self.execute_no_results(sock_info, generator)
#     556 else:
# --> 557     return self.execute_command(generator, write_concern, session)
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/bulk.py:367, in _Bulk.execute_command(self, generator, write_concern, session)
#     365 client = self.collection.database.client
#     366 with client._tmp_session(session) as s:
# --> 367     client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     369 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     370     _raise_bulk_write_error(full_result)
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/mongo_client.py:1532, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1524 """Execute an operation with at most one consecutive retries
#    1525
#    1526 Returns func()'s return value on success. On error retries the same
#    (...)
#    1529 Re-raises any exception thrown by func().
#    1530 """
#    1531 retryable = retryable and self.options.retry_writes and session and not session.in_transaction
# -> 1532 return self._retry_internal(retryable, func, session, bulk)
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/mongo_client.py:1565, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1563                 raise last_error
#    1564             retryable = False
# -> 1565         return func(session, sock_info, retryable)
#    1566 except ServerSelectionTimeoutError:
#    1567     if is_retrying():
#    1568         # The application may think the write was never attempted
#    1569         # if we raise ServerSelectionTimeoutError on the retry
#    1570         # attempt. Raise the original exception instead.
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/bulk.py:361, in _Bulk.execute_command.<locals>.retryable_bulk(session, sock_info, retryable)
#     360 def retryable_bulk(session, sock_info, retryable):
# --> 361     self._execute_command(
#     362         generator, write_concern, session, sock_info, op_id, retryable, full_result
#     363     )
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/bulk.py:318, in _Bulk._execute_command(self, generator, write_concern, session, sock_info, op_id, retryable, full_result)
#     316 ops = islice(run.ops, run.idx_offset, None)
#     317 # Run as many ops as possible in one command.
# --> 318 result, to_send = bwc.execute(cmd, ops, client)
#     320 # Retryable writeConcernErrors halt the execution of this run.
#     321 wce = result.get("writeConcernError", {})
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/message.py:1108, in _BulkWriteContext.execute(self, cmd, docs, client)
#    1107 def execute(self, cmd, docs, client):
# -> 1108     request_id, msg, to_send = self._batch_command(cmd, docs)
#    1109     result = self.write_command(cmd, request_id, msg, to_send)
#    1110     client._process_response(result, self.session)
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/message.py:1100, in _BulkWriteContext._batch_command(self, cmd, docs)
#    1098 def _batch_command(self, cmd, docs):
#    1099     namespace = self.db_name + ".$cmd"
# -> 1100     request_id, msg, to_send = _do_bulk_write_command(
#    1101         namespace, self.op_type, cmd, docs, self.check_keys, self.codec, self
#    1102     )
#    1103     if not to_send:
#    1104         raise InvalidOperation("cannot do an empty bulk write")
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/message.py:1603, in _do_bulk_write_command(namespace, operation, command, docs, check_keys, opts, ctx)
#    1601 """Bulk write commands entry point."""
#    1602 if ctx.sock_info.max_wire_version > 5:
# -> 1603     return _do_batched_op_msg(namespace, operation, command, docs, check_keys, opts, ctx)
#    1604 return _do_batched_write_command(namespace, operation, command, docs, check_keys, opts, ctx)
#
# File /usr/local/lib/python3.8/dist-packages/pymongo/message.py:1533, in _do_batched_op_msg(namespace, operation, command, docs, check_keys, opts, ctx)
#    1531 if ctx.sock_info.compression_context:
#    1532     return _batched_op_msg_compressed(operation, command, docs, check_keys, ack, opts, ctx)
# -> 1533 return _batched_op_msg(operation, command, docs, check_keys, ack, opts, ctx)
#
# InvalidDocument: documents must have only string keys, key was 0

# %% [markdown]
# ## Bonus: Importing a CSV file into a MySQL database

# %% [markdown]
# #### Connect to the MySQL database:
#
#
# ```
#
# import mysql.connector
# cnx = mysql.connector.connect(user='<username>', password='<password>', host='<hostname>', database='<database>')
# cursor = cnx.cursor()
#
#
#
# ```

# %%
import mysql.connector

cnx = mysql.connector.connect(user='root', password='Pucit12345#', host='localhost', db='churn')
cursor = cnx.cursor()

# %% [markdown]
# > **Note:** Replace `username`, `password`, `hostname`, and `database` with the appropriate values for your MySQL server.

# %% [markdown]
# #### Read the CSV file into a Pandas DataFrame:
#
# ```
#
# import pandas as pd
#
# df = pd.read_csv("<file>.csv")
#
#
#
# ```

# %%
df = pd.read_csv('datasets/churn_dataset.csv')
df.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# 1                13.7                 3                3.7
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
#
# [2 rows x 21 columns]

# %% [markdown]
# > **Note:** Replace `file` with the name of your CSV file.

# %% [markdown]
# #### Create a table in the MySQL database to store the data:
#
# ```
#
# table = "<table>"
# columns = ",".join(df.columns)
#
# query = f"CREATE TABLE IF NOT EXISTS {table} ({columns})"
# cursor.execute(query)
#
# ```
#
# > **Note:** Replace `table` with the name of the table you want to create.

# %%
table = "churn_table"
columns = ",".join(df.columns)

query = f"CREATE TABLE IF NOT EXISTS {table} ({columns})"
cursor.execute(query)

# %% [markdown]
# #### Insert Data Into Table

# %%
query = f"INSERT INTO {table} ({columns}) VALUES ({'%s,' * len(df.columns)})"
cursor.executemany(query, df.values.tolist())

# %% [markdown]
# #### Commit the changes and close the cursor and connection:

# %%
cnx.commit()
cursor.close()
cnx.close()
